# %% [markdown]
# # Proyecto

# %% [markdown]
# ## Objetivos del proyecto
# Predecir la cantidad de crímenes por categorías según el conjunto de datos.
# Contemplar:
# 1. La limpieza y adecuación de los datos, incluída su separación para entrenamiento y testeo.(*)
# 2. La transformación adecuada de los datos.
# 3. Selección de variables de entrada (Features) y su justificación.
# 4. Seleccion de características para el modelo, los hiperparámetros (si fuesen necesarios) y su justificación.
# 5. Selección del modelo y las métricas para su evaluación y su justificación.
# 6. Los métodos gráficos para la discusión del modelo.
# 7. Argumentar brevemente aplicaciones para la predicción realizada.
#
# \* Entregar el análisis de datos en un anexo, incluyendo links.

# %% [markdown]
# ## Sobre el formato de entrega
# * Para su entrega puede hacerlo en cualquier formato que incluya al menos un archivo llamado **Principal.ipybn** (Jupyter notebook). Puede utilizar Google Colab, Deepnote, Drive o Github, desde donde compartirá el archivo correspondiente.
#
# **IMPORTANTE** ¡¡¡Seamos responsables y respaldemos nuestros archivos para evitar incidentes que nos impidan cumplir la meta!!!

# %% [markdown]
# ## Sobre el contenido
# * Toda información que dé robustez a su trabajo, puede ser insertado en links adicionales al final del archivo principal o indicarlo en la sección correspondiente.
# * Se entenderá por transformación todo procesamiento de datos que sea objetivo de este curso, como las imputaciones de KNN imputer.
# * El código debe poder ejecutarse de manera simple (la ubicación de los archivos tendrá presente este punto).
# * Debe entregar el archivo con los resultados de la ejecución en la celda correspondiente.

# %% [markdown]
# ## Formato de entrega
# Debe incluir al inicio del documento de entrega:
# 1) El nombre del grupo indicado tal y como fue asignado: TP304-EQ0X ó TP304-EQXX.
# 2) El Nombre(s)/Apellido(s) de los integrantes.
# 3) El link a un vídeo de YouTube de 1 minuto de duración, demostrando la ejecución del código, una breve explicación y los resultados.
# 4) Todas las librerías instaladas, cuando sea necesario.
# 5) El código organizado en bloques, de forma prolija.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=62a9890a-2d98-4196-acb6-6f2a8f3e4e18' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
