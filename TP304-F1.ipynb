# %% [markdown]
# <h1>TP Chequeando datos </h1>
# Crimenes CABA 2018-2022
#
# 1. La limpieza y adecuación de los datos, incluída su separación para entrenamiento y testeo.(*)
# 2. La transformación adecuada de los datos.
# 3. Selección de variables de entrada (Features) y su justificación.
# 4. Seleccion de características para el modelo, los hiperparámetros (si fuesen necesarios) y su justificación.
# 5. Selección del modelo y las métricas para su evaluación y su justificación.
# 6. Los métodos gráficos para la discusión del modelo.
# 7. Argumentar brevemente aplicaciones para la predicción realizada.

# %%
#Importar Librarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %%
#open files 2018
df2018=pd.read_csv("delitos_2018.csv")
df2018.head()
# Out:
#    id-mapa  anio     mes        dia       fecha  franja  tipo     subtipo  \
# 0   500003  2018  AGOSTO    DOMINGO  2018-08-05    16.0  Robo  Robo total
# 1   500006  2018  AGOSTO      LUNES  2018-08-06    17.0  Robo  Robo total
# 2   500009  2018  AGOSTO  MIERCOLES  2018-08-08    22.0  Robo  Robo total
# 3   500012  2018  AGOSTO  MIERCOLES  2018-08-08    15.0  Robo  Robo total
# 4   500015  2018  AGOSTO    VIERNES  2018-08-10    12.0  Robo  Robo total
#
#   uso_arma uso_moto  barrio  comuna    latitud   longitud  cantidad
# 0       NO       NO  RETIRO     1.0 -34.580776 -58.387188         1
# 1       NO       NO  RETIRO     1.0 -34.580776 -58.387188         1
# 2       NO       NO  RETIRO     1.0 -34.580776 -58.387188         1
# 3       NO       NO  RETIRO     1.0 -34.595628 -58.386597         1
# 4       SI       NO  RETIRO     1.0 -34.581095 -58.385790         1

# %%
#open files 2019
df2019=pd.read_csv("delitos_2019.csv")
df2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149524 entries, 0 to 149523
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id-mapa   149524 non-null  int64
#  1   anio      149524 non-null  int64
#  2   mes       149524 non-null  object
#  3   dia       149524 non-null  object
#  4   fecha     149524 non-null  object
#  5   franja    149517 non-null  float64
#  6   tipo      149524 non-null  object
#  7   subtipo   149524 non-null  object
#  8   uso_arma  149524 non-null  object
#  9   uso_moto  149524 non-null  object
#  10  barrio    147364 non-null  object
#  11  comuna    147364 non-null  float64
#  12  latitud   147367 non-null  float64
#  13  longitud  147367 non-null  float64
#  14  cantidad  149524 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 17.1+ MB

# %%
#open files 2020
df2020=pd.read_csv("delitos_2020.csv")
df2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86175 entries, 0 to 86174
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id-mapa   86175 non-null  int64
#  1   anio      86175 non-null  int64
#  2   mes       86175 non-null  object
#  3   dia       86175 non-null  object
#  4   fecha     86175 non-null  object
#  5   franja    85656 non-null  float64
#  6   tipo      86175 non-null  object
#  7   subtipo   86175 non-null  object
#  8   uso_arma  86175 non-null  object
#  9   uso_moto  86175 non-null  object
#  10  barrio    84876 non-null  object
#  11  comuna    84876 non-null  float64
#  12  latitud   84877 non-null  float64
#  13  longitud  84877 non-null  float64
#  14  cantidad  86175 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 9.9+ MB

# %%
#open files 2021
df2021= pd.read_csv("delitos_2021.csv")
df2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111962 entries, 0 to 111961
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id-mapa   111962 non-null  int64
#  1   anio      111962 non-null  int64
#  2   mes       111962 non-null  object
#  3   dia       111962 non-null  object
#  4   fecha     111962 non-null  object
#  5   franja    110222 non-null  float64
#  6   tipo      111962 non-null  object
#  7   subtipo   111962 non-null  object
#  8   uso_arma  111962 non-null  object
#  9   uso_moto  111962 non-null  object
#  10  barrio    109378 non-null  object
#  11  comuna    109378 non-null  float64
#  12  latitud   109383 non-null  float64
#  13  longitud  109383 non-null  float64
#  14  cantidad  111962 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 12.8+ MB

# %%
#open files 2022
df2022=pd.read_csv("delitos_2022.csv")
df2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140918 entries, 0 to 140917
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id-mapa   140918 non-null  int64
#  1   anio      140918 non-null  int64
#  2   mes       140918 non-null  object
#  3   dia       140918 non-null  object
#  4   fecha     140918 non-null  object
#  5   franja    140871 non-null  float64
#  6   tipo      140918 non-null  object
#  7   subtipo   140918 non-null  object
#  8   uso_arma  140918 non-null  object
#  9   uso_moto  140918 non-null  object
#  10  barrio    138527 non-null  object
#  11  comuna    138525 non-null  float64
#  12  latitud   138533 non-null  float64
#  13  longitud  138533 non-null  float64
#  14  cantidad  140918 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 16.1+ MB

# %%
#Unificar tablas
df_CABA= pd.concat([df2018,df2019,df2020,df2021,df2022],axis=0)
df_CABA.to_csv("df_CABA.csv", index=False)
df_CABA
# Out:
#         id-mapa  anio        mes        dia       fecha  franja      tipo  \
# 0        500003  2018     AGOSTO    DOMINGO  2018-08-05    16.0      Robo
# 1        500006  2018     AGOSTO      LUNES  2018-08-06    17.0      Robo
# 2        500009  2018     AGOSTO  MIERCOLES  2018-08-08    22.0      Robo
# 3        500012  2018     AGOSTO  MIERCOLES  2018-08-08    15.0      Robo
# 4        500015  2018     AGOSTO    VIERNES  2018-08-10    12.0      Robo
# ...         ...   ...        ...        ...         ...     ...       ...
# 140913  1114494  2022  DICIEMBRE     JUEVES  2022-12-15    19.0  Vialidad
# 140914  1114495  2022  DICIEMBRE    VIERNES  2022-12-16    13.0  Vialidad
# 140915  1114496  2022  DICIEMBRE     JUEVES  2022-12-22    11.0  Vialidad
# 140916  1114497  2022  DICIEMBRE    VIERNES  2022-12-30    18.0  Vialidad
# 140917  1114498  2022  DICIEMBRE     SABADO  2022-12-31    21.0  Vialidad
#
#                               subtipo uso_arma uso_moto             barrio  \
# ...

# %%
df_CABA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 638034 entries, 0 to 140917
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id-mapa   638034 non-null  int64
#  1   anio      638034 non-null  int64
#  2   mes       638034 non-null  object
#  3   dia       638034 non-null  object
#  4   fecha     638034 non-null  object
#  5   franja    635716 non-null  float64
#  6   tipo      638034 non-null  object
#  7   subtipo   638034 non-null  object
#  8   uso_arma  638034 non-null  object
#  9   uso_moto  638034 non-null  object
#  10  barrio    616397 non-null  object
#  11  comuna    616395 non-null  float64
#  12  latitud   616469 non-null  float64
#  13  longitud  616469 non-null  float64
#  14  cantidad  638034 non-null  int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 77.9+ MB

# %%
#Verificar duplicados
df_CABA.duplicated().sum(axis=0)
# Out:
# 0

# %%
#Verificar nulos
df_CABA.isnull().sum(axis=0)
# Out:
# id-mapa         0
# anio            0
# mes             0
# dia             0
# fecha           0
# franja       2318
# tipo            0
# subtipo         0
# uso_arma        0
# uso_moto        0
# barrio      21637
# comuna      21639
# latitud     21565
# longitud    21565
# cantidad        0
# dtype: int64

# %%
#Contar valores en cada columna
missing_data = df_CABA.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# id-mapa
# id-mapa
# False    638034
# Name: count, dtype: int64
#
# anio
# anio
# False    638034
# Name: count, dtype: int64
#
# mes
# mes
# False    638034
# Name: count, dtype: int64
#
# dia
# dia
# False    638034
# Name: count, dtype: int64
#
# fecha
# fecha
# False    638034
# Name: count, dtype: int64
#
# franja
# franja
# False    635716
# True       2318
# Name: count, dtype: int64
#
# tipo
# tipo
# False    638034
# Name: count, dtype: int64
#
# subtipo
# subtipo
# False    638034
# Name: count, dtype: int64
#
# uso_arma
# uso_arma
# False    638034
# Name: count, dtype: int64
#
# uso_moto
# uso_moto
# False    638034
# Name: count, dtype: int64
#
# barrio
# barrio
# False    616397
# True      21637
# Name: count, dtype: int64
#
# comuna
# comuna
# False    616395
# True      21639
# Name: count, dtype: int64
#
# latitud
# latitud
# False    616469
# True      21565
# Name: count, dtype: int64
#
# longitud
# longitud
# False    616469
# True      21565
# ...

# %%
#Convertir numero de Comuna,Franja a entero
df_CABA.comuna= df_CABA.comuna.astype('Int64')
df_CABA.franja= df_CABA.franja.astype('Int64')

# %%
#Convertir fechas
df_CABA['fecha'] = pd.to_datetime(df_CABA['fecha'], format='%Y-%m-%d')
print(df_CABA['fecha'])
# Out:
# 0        2018-08-05
# 1        2018-08-06
# 2        2018-08-08
# 3        2018-08-08
# 4        2018-08-10
#             ...
# 140913   2022-12-15
# 140914   2022-12-16
# 140915   2022-12-22
# 140916   2022-12-30
# 140917   2022-12-31
# Name: fecha, Length: 638034, dtype: datetime64[ns]

# %%
#Convertir tipo de fecha anio, mes
df_CABA['anio'] = df_CABA['fecha'].dt.year
df_CABA['mes'] = df_CABA['fecha'].dt.month
df_CABA.info()
#pendiente convertir  dia, franja
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 638034 entries, 0 to 140917
# Data columns (total 15 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id-mapa   638034 non-null  int64
#  1   anio      638034 non-null  int32
#  2   mes       638034 non-null  int32
#  3   dia       638034 non-null  object
#  4   fecha     638034 non-null  datetime64[ns]
#  5   franja    635716 non-null  Int64
#  6   tipo      638034 non-null  object
#  7   subtipo   638034 non-null  object
#  8   uso_arma  638034 non-null  object
#  9   uso_moto  638034 non-null  object
#  10  barrio    616397 non-null  object
#  11  comuna    616395 non-null  Int64
#  12  latitud   616469 non-null  float64
#  13  longitud  616469 non-null  float64
#  14  cantidad  638034 non-null  int64
# dtypes: Int64(2), datetime64[ns](1), float64(2), int32(2), int64(2), object(6)
# memory usage: 74.2+ MB

# %%
#Verificar si son los mismos datos faltantes en columnas Latitud y Longitud 
df_CABA[(df_CABA['latitud'].isna() & df_CABA['longitud'].isna())]
# Out:
#         id-mapa  anio  mes        dia      fecha  franja      tipo  \
# 294      500885  2018    8      LUNES 2018-08-06      14      Robo
# 297      500894  2018    8      LUNES 2018-08-06      15      Robo
# 301      500906  2018    8     MARTES 2018-08-07      20      Robo
# 302      500909  2018    8  MIERCOLES 2018-08-08      15      Robo
# 303      500912  2018    8      LUNES 2018-08-06      21      Robo
# ...         ...   ...  ...        ...        ...     ...       ...
# 121772   918135  2022    2      LUNES 2022-02-14      22  Lesiones
# 121773   918143  2022    2     MARTES 2022-02-08      23  Amenazas
# 121774   918144  2022    4      LUNES 2022-04-11      17  Amenazas
# 121775   918145  2022    7     MARTES 2022-07-05      10  Amenazas
# 121776   918146  2022   12     MARTES 2022-12-06      11  Amenazas
#
#                  subtipo uso_arma uso_moto barrio  comuna  latitud  longitud  \
# 294           Robo total       SI       NO    NaN    <NA>      NaN       NaN
# ...

# %%
#Completar datos faltantes de franja con promedio 
#avg_franja=df_CABA['franja'].astype('float').mean(axis=0)
#print("El promedio de franja es:", avg_franja)

# %%
#df_CABA["franja"].replace(np.nan, avg_franja)

# %%
#Eliminar datos nulos y columnas 
df_CABA_clean= df_CABA.dropna(subset= ['latitud','longitud'])
df_CABA_clean= df_CABA_clean.drop(columns=['id-mapa'])

# %%
df_CABA_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 616469 entries, 0 to 140917
# Data columns (total 14 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   anio      616469 non-null  int32
#  1   mes       616469 non-null  int32
#  2   dia       616469 non-null  object
#  3   fecha     616469 non-null  datetime64[ns]
#  4   franja    614459 non-null  Int64
#  5   tipo      616469 non-null  object
#  6   subtipo   616469 non-null  object
#  7   uso_arma  616469 non-null  object
#  8   uso_moto  616469 non-null  object
#  9   barrio    616395 non-null  object
#  10  comuna    616395 non-null  Int64
#  11  latitud   616469 non-null  float64
#  12  longitud  616469 non-null  float64
#  13  cantidad  616469 non-null  int64
# dtypes: Int64(2), datetime64[ns](1), float64(2), int32(2), int64(1), object(6)
# memory usage: 67.0+ MB

# %%
df_CABA_clean.hist()
# Out:
# array([[<Axes: title={'center': 'anio'}>,
#         <Axes: title={'center': 'mes'}>,
#         <Axes: title={'center': 'fecha'}>],
#        [<Axes: title={'center': 'franja'}>,
#         <Axes: title={'center': 'comuna'}>,
#         <Axes: title={'center': 'latitud'}>],
#        [<Axes: title={'center': 'longitud'}>,
#         <Axes: title={'center': 'cantidad'}>, <Axes: >]], dtype=object)

# %%
#Guardar archivo
df_CABA_clean.to_csv("df_CABA_clean.csv", index=False)
